# %% [markdown]
# ## 8. Results and Evaluation
#
# ### Model Performance
# - Compare baseline vs advanced models
# - Highlight best-performing model
#
# ### Feature Importance
# - Which variables contribute most to predictions?
# - Does 311 data improve performance?
#
# ### Key Findings
# - Identify meaningful predictors
# - Assess predictive power of 311 requests

# %% [markdown]
# ## 9. Insights and Business Value
#
# ### Key Insights
# - Time windows with highest risk
# - Neighborhoods with elevated activity
# - Relationship between 311 requests and crime
#
# ### Example Insight
# "Areas with high abandoned vehicle reports show increased theft incidents within the following week."
#
# ### Operational Impact
# - Inform resource allocation
# - Support proactive interventions

# %% [markdown]
# ## 10. Limitations and Ethical Considerations
#
# ### Limitations
# - Data quality issues
# - Underreporting of incidents
# - Correlation vs causation
#
# ### Ethical Considerations
# - Predictions are at aggregate level only
# - Model should not be used for profiling individuals
# - Potential bias in reporting patterns

# %% [markdown]
# ## 11. Next Steps
#
# - Incorporate weather data
# - Add demographic datasets
# - Improve spatial modeling (GIS-based features)
# <!-- - Deploy dashboard (Power BI or Tableau) -->

# %% [markdown]
# ## 12. Conclusion
#
# This project demonstrates how combining operational data (311 requests) with public safety data can provide meaningful insights into crime risk patterns.
#
# The results highlight the potential for data-driven decision-making in urban environments.
